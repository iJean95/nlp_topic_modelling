# %%
import pandas as pd
from collections import OrderedDict
import requests
import matplotlib.pyplot as plt

# %%
def getFile(file):
    try:
        return pd.read_csv(file,sep=";",header=0,na_values=["-"])
    except Exception:
        print('Issue with csv file' )

# %%
data_all = pd.read_csv(list_files_in[0],sep="\t",header=0, na_values=["-"],encoding='utf-16')
print(data_all) #shows whole table
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-8e94a5946cb3> in <module>
# ----> 1 data_all = pd.read_csv(list_files_in[0],sep="\t",header=0, na_values=["-"],encoding='utf-16')
#       2 print(data_all) #shows whole table
#       3
#       4
#       5
#
# NameError: name 'list_files_in' is not defined

# %%
# default='warn' #deactivate warning
pd.options.mode.chained_assignment = None 

#filter only on comments and interesting columns
df = data_all[["ID", "Comment_column"]]
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-906521c1da85> in <module>
#       3
#       4 #filter only on English comments and interesting columns
# ----> 5 df = data_all[["ID", "Comment_column"]]
#       6 df.head()
#
# NameError: name 'data_all' is not defined

# %%
#remove rows where no comments
df= df.dropna(thresh=1)
df.head(200)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c9efffda9d19> in <module>
#       1 #remove rows where no comments
# ----> 2 df= df.dropna(thresh=1)
#       3 df.head(200)
#
# NameError: name 'df' is not defined

# %%
pip install googletrans
# Out:
# Collecting googletrans
#   Downloading googletrans-3.0.0.tar.gz (17 kB)
# Collecting httpx==0.13.3
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 2.4 MB/s eta 0:00:011
# Collecting sniffio
#   Downloading sniffio-1.1.0-py3-none-any.whl (4.5 kB)
# Collecting hstspreload
#   Downloading hstspreload-2020.9.22-py3-none-any.whl (959 kB)
#      |████████████████████████████████| 959 kB 5.9 MB/s eta 0:00:01
# Collecting httpcore==0.9.*
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 3.3 MB/s  eta 0:00:01
# Requirement already satisfied: idna==2.* in /Users/jean/opt/anaconda3/lib/python3.7/site-packages (from httpx==0.13.3->googletrans) (2.8)
# Collecting rfc3986<2,>=1.3
#   Downloading rfc3986-1.4.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: chardet==3.* in /Users/jean/opt/anaconda3/lib/python3.7/site-packages (from httpx==0.13.3->googletrans) (3.0.4)
# Requirement already satisfied: certifi in /Users/jean/opt/anaconda3/lib/python3.7/site-packages (from httpx==0.13.3->googletrans) (2019.11.28)
# Collecting h2==3.*
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 6.1 MB/s  eta 0:00:01
# Collecting h11<0.10,>=0.8
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 3.9 MB/s  eta 0:00:01
# Collecting hyperframe<6,>=5.2.0
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.0.0-py3-none-any.whl size=15734 sha256=5cb69b051e316fe338e2e1e2e9076b227702b0dd477940631c1a4d103b7d8403
#   Stored in directory: /Users/jean/Library/Caches/pip/wheels/20/da/eb/a54579056f265eede0417df537dd56d3df5b9eb2b25df0003d
# Successfully built googletrans
# Installing collected packages: sniffio, hstspreload, hyperframe, hpack, h2, h11, httpcore, rfc3986, httpx, googletrans
# Successfully installed googletrans-3.0.0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2020.9.22 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 rfc3986-1.4.0 sniffio-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import time
import sys
# !conda install --yes --prefix {sys.prefix} tqdm
from tqdm import tqdm


tqdm.pandas()
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/jean/opt/anaconda3
#
#   added / updated specs:
#     - tqdm
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.7.22  |                0         124 KB
#     certifi-2020.6.20          |           py37_0         156 KB
#     conda-4.8.5                |           py37_0         2.9 MB
#     openssl-1.1.1h             |       haf1e3a3_0         2.2 MB
#     tqdm-4.49.0                |             py_0          55 KB
#     ------------------------------------------------------------
#                                            Total:         5.4 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2020.6.2~ --> pkgs/main::ca-certificates-2020.7.22-0
#   openssl            conda-forge::openssl-1.1.1g-haf1e3a3_1 --> pkgs/main::openssl-1.1.1h-haf1e3a3_0
#   tqdm                                          4.46.0-py_0 --> 4.49.0-py_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            conda-forge::certifi-2020.6.20-py37hc~ --> pkgs/main::certifi-2020.6.20-py37_0
#   conda              conda-forge::conda-4.8.5-py37hc8dfbb8~ --> pkgs/main::conda-4.8.5-py37_0
#
#
#
# Downloading and Extracting Packages
# openssl-1.1.1h       | 2.2 MB    | ##################################### | 100%
# ca-certificates-2020 | 124 KB    | ##################################### | 100%
# certifi-2020.6.20    | 156 KB    | ##################################### | 100%
# conda-4.8.5          | 2.9 MB    | ##################################### | 100%
# tqdm-4.49.0          | 55 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# /Users/jean/opt/anaconda3/lib/python3.7/site-packages/tqdm/std.py:670: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
from googletrans import Translator
translator = Translator()

def language_translation(original_text):
    #print(row)
    original_text = str(original_text)
    result = translator.translate(original_text, dest='en').text

    return result

# %%
df['Comment_translated'] = df.progress_apply(lambda x:language_translation(x),axis=1)
print("done")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-8910e9714278> in <module>
# ----> 1 df['Comment_translated'] = df.progress_apply(lambda x:language_translation(x),axis=1)
#       2 print("done")
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#       Work Location  Job Level                               BU  \
# 1      South Africa          1                           Africa
# 2           Belgium          1                           Africa
# 3           Belgium          4                           Africa
# 4            France          1                           Africa
# 6               USA          7                           Africa
# 7           Morocco          4                           Africa
# 8            France          1                           Africa
# 9      South Africa          8                           Africa
# 10          Belgium          8                           Africa
# 11          Morocco         10                           Africa
# 12          Morocco         10                           Africa
# 13     South Africa          5                           Africa
# 14     South Africa          5                           Africa
# 15     South Africa          6                           Africa
# 16     South Africa          6                           Africa
# 17     South Africa          6                           Africa
# 18     South Africa          6                           Africa
# 19     South Africa          6                           Africa
# 20     South Africa          6                           Africa
# 21          Morocco         10                           Africa
# 22          Morocco         10                           Africa
# 23     South Africa         11                           Africa
# 24     South Africa         11                           Africa
# 26     South Africa          6                           Africa
# 28     South Africa         11                           Africa
# 30     South Africa         11                           Africa
# 31     South Africa         11                           Africa
# 32     South Africa         11                           Africa
# 33     South Africa         11                           Africa
# 34     South Africa         11                           Africa
# ...             ...        ...                              ...
# 83604           USA       1888                    North America
# 83605           USA       1998                    North America
# 83606           USA       1998                    North America
# 83607           USA       1998                    North America
# 83611           USA       1939                    North America
# 83614           USA       1935                    North America
# 83615           USA       1935                    North America
# 83616           USA       1935                    North America
# 83617           USA       1935                    North America
# 83618           USA       1996                    North America
# 83619        Canada       1869                    North America
# 83620           USA       1914                    North America
# 83622           USA       1888                    North America
# 83623           USA       1951                    North America
# 83625           USA       1890                    North America
# 83627           USA       1888                    North America
# 83628           USA       1888                    North America
# 83629           USA       1950                    North America
# 83630           USA       1943                    North America
# 83632           USA       1888                    North America
# 83633           USA       1908                    North America
# 83634           USA       1911                    North America
# 83635           USA       1911                    North America
# 83636           USA       1911                    North America
# 83639           USA       1910                    North America
# 83642        France       1825                          Newcorp
# 83643        France       1071                      France BtoB
# 83644         Spain       2034  North, South and Eastern Europe
# 83645        France       1263                      France BtoB
# 83646         Italy       1760         Global Energy Management
#
#                                                  manager  GENDER      AGE  \
# 1                                                Manager    Male  45 - 55
# 2                                    Manager of managers    Male  35 - 45
# 3      Expert/professional without people management ...    Male  35 - 45
# 4                                                Manager    Male  35 - 45
# 6                                    Manager of managers    Male  45 - 55
# 7      Expert/professional without people management ...    Male  35 - 45
# 8                                                Manager    Male  35 - 45
# 9      Expert/professional without people management ...  Female  35 - 45
# 10     Expert/professional without people management ...    Male  35 - 45
# 11     Employee without people management responsibility    Male  35 - 45
# 12                                               Manager    Male  45 - 55
# 13                                   Manager of managers    Male  45 - 55
# 14     Employee without people management responsibility    Male  45 - 55
# 15     Employee without people management responsibility  Female  25 - 35
# 16                                               Manager  Female  25 - 35
# 17                                               Manager    Male  25 - 35
# 18     Employee without people management responsibility  Female  25 - 35
# 19     Employee without people management responsibility    Male  25 - 35
# 20     Employee without people management responsibility  Female     < 25
# 21                                               Manager    Male  25 - 35
# 22     Employee without people management responsibility    Male  35 - 45
# 23                                               Manager    Male  45 - 55
# 24     Expert/professional without people management ...    Male  25 - 35
# 26     Employee without people management responsibility    Male  25 - 35
# 28     Employee without people management responsibility    Male  45 - 55
# 30     Employee without people management responsibility  Female     < 25
# 31     Employee without people management responsibility  Female  25 - 35
# 32     Employee without people management responsibility  Female  45 - 55
# 33     Employee without people management responsibility  Female  45 - 55
# 34     Employee without people management responsibility  Female  45 - 55
# ...                                                  ...     ...      ...
# 83604  Expert/professional without people management ...    Male     > 55
# 83605  Expert/professional without people management ...  Female  35 - 45
# 83606  Expert/professional without people management ...  Female  35 - 45
# 83607  Employee without people management responsibility  Female     < 25
# 83611                                Manager of managers    Male  45 - 55
# 83614  Expert/professional without people management ...    Male  25 - 35
# 83615                                            Manager    Male  35 - 45
# 83616  Expert/professional without people management ...    Male  25 - 35
# 83617  Expert/professional without people management ...  Female  35 - 45
# 83618  Expert/professional without people management ...  Female  25 - 35
# 83619                                Manager of managers    Male  35 - 45
# 83620                                            Manager    Male  35 - 45
# 83622                                Manager of managers    Male  45 - 55
# 83623                                Manager of managers  Female  45 - 55
# 83625  Employee without people management responsibility    Male  45 - 55
# 83627  Employee without people management responsibility    Male  25 - 35
# 83628  Employee without people management responsibility    Male  25 - 35
# 83629  Employee without people management responsibility    Male     < 25
# 83630  Expert/professional without people management ...    Male  35 - 45
# 83632                                            Manager  Female  45 - 55
# 83633  Expert/professional without people management ...    Male  45 - 55
# 83634  Expert/professional without people management ...    Male  45 - 55
# 83635  Employee without people management responsibility  Female  35 - 45
# 83636  Expert/professional without people management ...    Male  25 - 35
# 83639  Expert/professional without people management ...  Female  45 - 55
# 83642                                Manager of managers  Female  45 - 55
# 83643  Employee without people management responsibility    Male  25 - 35
# 83644                                            Manager    Male  35 - 45
# 83645                                            Manager  Female  25 - 35
# 83646                                Manager of managers    Male  35 - 45
#
#                                TENURE Engagement Segmentation Engagement  \
# 1                    10 years or more              Disengaged      0,375
# 2                    10 years or more             Unsupported      0,875
# 3                    10 years or more             Unsupported       0,75
# 4                    10 years or more              Disengaged        0,5
# 6                    10 years or more     Sustainably Engaged          1
# 7                    10 years or more             Unsupported      0,875
# 8      5 years but less than 10 years     Sustainably Engaged      0,875
# 9                    10 years or more              Disengaged       0,25
# 10                   10 years or more                Detached      0,625
# 11       1 year but less than 5 years             Unsupported       0,75
# 12                   10 years or more     Sustainably Engaged          1
# 13       1 year but less than 5 years     Sustainably Engaged          1
# 14       1 year but less than 5 years              Disengaged       0,25
# 15       1 year but less than 5 years     Sustainably Engaged          1
# 16       1 year but less than 5 years             Unsupported       0,75
# 17       1 year but less than 5 years                Detached       0,75
# 18       1 year but less than 5 years             Unsupported      0,875
# 19       1 year but less than 5 years     Sustainably Engaged          1
# 20       1 year but less than 5 years             Unsupported       0,75
# 21       1 year but less than 5 years              Disengaged      0,375
# 22       1 year but less than 5 years     Sustainably Engaged          1
# 23       1 year but less than 5 years     Sustainably Engaged          1
# 24       1 year but less than 5 years              Disengaged       0,75
# 26       1 year but less than 5 years     Sustainably Engaged          1
# 28       1 year but less than 5 years                Detached       0,75
# 30       1 year but less than 5 years              Disengaged       0,25
# 31                   Less than 1 year     Sustainably Engaged          1
# 32       1 year but less than 5 years             Unsupported      0,875
# 33       1 year but less than 5 years             Unsupported      0,875
# 34       1 year but less than 5 years     Sustainably Engaged          1
# ...                               ...                     ...        ...
# 83604    1 year but less than 5 years     Sustainably Engaged          1
# 83605  5 years but less than 10 years              Disengaged      0,625
# 83606    1 year but less than 5 years                Detached       0,75
# 83607                Less than 1 year                Detached          1
# 83611                10 years or more     Sustainably Engaged          1
# 83614                10 years or more              Disengaged        0,5
# 83615                10 years or more                Detached      0,875
# 83616    1 year but less than 5 years     Sustainably Engaged          1
# 83617  5 years but less than 10 years             Unsupported          1
# 83618    1 year but less than 5 years     Sustainably Engaged          1
# 83619                10 years or more             Unsupported       0,75
# 83620                10 years or more     Sustainably Engaged          1
# 83622                10 years or more             Unsupported      0,875
# 83623                10 years or more     Sustainably Engaged          1
# 83625                10 years or more             Unsupported          1
# 83627                10 years or more                Detached      0,875
# 83628    1 year but less than 5 years     Sustainably Engaged          1
# 83629    1 year but less than 5 years             Unsupported      0,875
# 83630    1 year but less than 5 years     Sustainably Engaged          1
# 83632                10 years or more     Sustainably Engaged          1
# 83633                Less than 1 year     Sustainably Engaged          1
# 83634  5 years but less than 10 years     Sustainably Engaged          1
# 83635    1 year but less than 5 years             Unsupported          1
# 83636                Less than 1 year             Unsupported       0,75
# 83639    1 year but less than 5 years              Disengaged      0,625
# 83642                Less than 1 year                Detached      0,875
# 83643  5 years but less than 10 years     Sustainably Engaged          1
# 83644                10 years or more     Sustainably Engaged          1
# 83645  5 years but less than 10 years     Sustainably Engaged          1
# 83646                10 years or more                Detached          1
#
#                                                     Cmt1  \
# 1      Les activités du groupe Engie sont en ligne av...
# 2      La mission d'ENGIE : leader in energy transiti...
# 3      - Variety of opportunities / job mobility - Ab...
# 4      Développer l'accès à l'énergie est un facteur ...
# 6      Mobility, diverse staff and socially conscious...
# 7      - L'appartenance à un grand groupe; - Ma contr...
# 8      Prise de responsabilités grandissantes. Transp...
# 9      I enjoy working for ENGIE as it allows me the ...
# 10                                                   NaN
# 11             Le contacte avec les clients sur chantier
# 12                   Transparence et esprit d'évolution.
# 13     1 An abundance of opportunities for personal g...
# 14     I AM NOT HAPPY WORKING AT AVON PEAKING POWER P...
# 15     The Company is still developing in Northern Ca...
# 16     I am proud of being part of company that promo...
# 17     The Engie BU is a good place for career growth...
# 18                          Safety is the first priority
# 19     The opportunities that await, for doing good w...
# 20                              ENGIE life saving rules.
# 21     Je pense pas avoir des possibilités de dévelop...
# 22                                                    ??
# 23     Its a more professional company with inspiring...
# 24                                                   NaN
# 26     Care for environment and its employees. Develo...
# 28     Employees must be paid if they work holidays a...
# 30     Everyone need to get paid according to the wor...
# 31     The adversity provided to accommodate everyone...
# 32     i am unable to actually answer this question t...
# 33     I am glad working under Engie and I do believe...
# 34     It will help and give us courage to be appreci...
# ...                                                  ...
# 83604  The energy and dedication of my fellow employe...
# 83605  I like the steps we're taking as part of the z...
# 83606  Learning & development programs should be impl...
# 83607                              The work environment.
# 83611                        the forward thinking vision
# 83614  Socially responsible. Prioritizing sustainabil...
# 83615                                                NaN
# 83616  The opportunity to grow professionally. This i...
# 83617  Identified with its purpose International cult...
# 83618  The purpose of our company, the impact we want...
# 83619  1/ I 200% align myself with ENGIE's vision. EN...
# 83620  I am very impressed with the radical decisions...
# 83622  Being able to help customers meet their financ...
# 83623  The renewable and diversified industry that we...
# 83625  I don't feel like I am at work I feel like I a...
# 83627                                                NaN
# 83628  I like that working for ENGIE has given me the...
# 83629  The people I work with on my team. There is a ...
# 83630  Innovative culture to lead clients to new ener...
# 83632  Work/Life balance, great projects for our cust...
# 83633  Environment is challenging/safe and impressed ...
# 83634                    Engie is a good place to work .
# 83635  Diversity, flexibility, opportunities for grow...
# 83636  What I like most about working at ENGIE is the...
# 83639                         The People and my Director
# 83642  Le positionnement de l’entreprise, en pointe d...
# 83643  la liberté que me laisse mon responsable hiéra...
# 83644  (i) Su estrategia, que ha mantenido coherencia...
# 83645  La stratégie zéro carbone, les personnes engag...
# 83646  In GEM most of us have or have had the chance ...
#
#                                                     Cmt2  \
# 1      1 - Mise en place d’une politique de développe...
# 2                                                    NaN
# 3      Empower people and BUs more by creating a flat...
# 4      Ambiance de travail, relation supérieur/subord...
# 6      HR. Specifically the Southern Africa HR depart...
# 7      un éventuel assouplissement des process et des...
# 8      Les augmentations de salaires devraient être p...
# 9      I would finalize the 3 year long implementatio...
# 10     Stop political appointments; Increase diversif...
# 11     La méthode de recrutement. Je passerai des ent...
# 12     Amelioartaion des service support (achat, outi...
# 13     Formalize benchmarking across the globe for En...
# 14                                          REMUNERATION
# 15                                         Not sure far!
# 16     Equality is not practiced I would start with t...
# 17     I would remove the micro managing tendencies o...
# 18     A better way of communication between employee...
# 19     Consider living situations of employees weathe...
# 20     -Proper communication. -Respect and being rewa...
# 21                                                   NaN
# 22                                                  rien
# 23     The ordering process of goods needs to be more...
# 24     Improve the approach to client service deliver...
# 26     Mindset of other employees, especially when it...
# 28     I will always have a meeting with my employees...
# 30     Their hiring skill. First of all, jobs are not...
# 31     I have not come across with any situation that...
# 32                                                   NaN
# 33                                      Not sure for now
# 34     If Engie can change the way our managers treat...
# ...                                                  ...
# 83604  The IT department needs to simplify all the ch...
# 83605  I would dedicate more resources to the integra...
# 83606  To reach a zero-carbon goal, we have to think ...
# 83607  Exempt and Non Exempt employees should have th...
# 83611  allign return expectations with the market rea...
# 83614                                                NaN
# 83615  - decloisoner - mode de decision plus clair et...
# 83616  I have worked in more than one BU and the mana...
# 83617  More collaboration and flexibility is needed t...
# 83618  Making the purpose more operational, being rem...
# 83619  1/ I'm concerned with the lack of consistency ...
# 83620  I understand one of ENGIE's primary mantra is ...
# 83622  It is not clear to me how we intend to integra...
# 83623  This is for other BU that I intracte with, Con...
# 83625                                                NaN
# 83627  Top management needs to be more engaged and no...
# 83628  I believe that the first thing i would change ...
# 83629  I think as a whole there is some distrust with...
# 83630  Have everybody be aware of all the functionali...
# 83632  Limiting travel policies at the end of the yea...
# 83633  I'll provide an opportunity to upgrade require...
# 83634                                                NaN
# 83635  better tools/systems/proceses for efficiency. ...
# 83636  What I would change at ENGIE Resources would b...
# 83639                        Systems and reduce nepotism
# 83642                           Un peu tôt pour répondre
# 83643                                      aucune idée !
# 83644  Reducir la inercia hacia el cambio que dificul...
# 83645  Je simplifierai les process pour m’assurer que...
# 83646  I will fairly and pragmatically re-assess peop...
#
#                                                     Cmt3  \
# 1      Les nouvelles puissances de notre monde - Chin...
# 2                                                    NaN
# 3      ENGIE has some key assets like its industrial ...
# 4      Parce que Engie a su très tôt inverser son mod...
# 6            To promote growth and change in new markets
# 7      L'équilibre qu'a su trouver le groupe dans la ...
# 8                                                    NaN
# 9      To allow people access to reliable and afforda...
# 10                                                   NaN
# 11     Oui il faut l inventer, et s engager a cent po...
# 12                                      Oui, absolument.
# 13                                            No comment
# 14                                            NO COMMENT
# 15                   To provide the society with energy.
# 16       to save the environment for future generations.
# 17     To ensure growth in the Energy sector and deve...
# 18                                                   NaN
# 19     To be able to survive for more years and bring...
# 20                         To reduce carbon house gases.
# 21                                                   NaN
# 22                                                    ??
# 23                                    To set an example.
# 24                                                   NaN
# 26     To minimize pollution and environmental concerns.
# 28                                       People will die
# 30                                            No opinion
# 31       To reduce all the bad effects on climate change
# 32      so that it can do something about climate change
# 33     I believe Engie can provide solutions to the c...
# 34     Trust them they can bring change to South Afri...
# ...                                                  ...
# 83604  The need is there for businesses like Engie to...
# 83605  ENGIE is very admirable in it's shift towards ...
# 83606  We should all hold the responsibility of takin...
# 83607  It should be created for us to have a more eff...
# 83611  because it promotes the necessary environment ...
# 83614                                                NaN
# 83615                              question pretentieuse
# 83616  To dignify people by giving them access to ene...
# 83617  We need companies that push these changes. We ...
# 83618  To lead/foster the changes in the energy secto...
# 83619                                                NaN
# 83620  We need ENGIE and many more companies like ENG...
# 83622  I think free market forces driving renewable e...
# 83623  Because it provides the products and delivers ...
# 83625                                                NaN
# 83627                                                NaN
# 83628  to ensure the future of our planet and the giv...
# 83629                                                NaN
# 83630  To ensure energy, which doesn't fit anymore in...
# 83632  Lack of robust electrical grid in most of Cali...
# 83633                                           Not sure
# 83634  Engie promotes clean energy and cares about th...
# 83635  It should be created to contribute to positive...
# 83636  If ENGIE did not exist it should be created be...
# 83639                                    to provide jobs
# 83642  Pour sa capacité à assembler de nouvelles solu...
# 83643                                 ne se prononce pas
# 83644  Porque su apuesta de ENGIE por la des-carboniz...
# 83645  Pour apporter des solutions zéro carbone aux c...
# 83646  Because today they are moving forward and tran...
#
#       language_detected_cmt1  \
# 1                         fr
# 2                         fr
# 3                         en
# 4                         fr
# 6                         en
# 7                         fr
# 8                         fr
# 9                         en
# 10                       NaN
# 11                        fr
# 12                        fr
# 13                        en
# 14                        en
# 15                        en
# 16                        en
# 17                        en
# 18                        en
# 19                        en
# 20                        en
# 21                        fr
# 22                        en
# 23                        en
# 24                       NaN
# 26                        en
# 28                        en
# 30                        en
# 31                        en
# 32                        en
# 33                        en
# 34                        en
# ...                      ...
# 83604                     en
# 83605                     en
# 83606                     en
# 83607                     en
# 83611                     en
# 83614                     en
# 83615                    NaN
# 83616                     en
# 83617                     en
# 83618                     en
# 83619                     en
# 83620                     en
# 83622                     en
# 83623                     en
# 83625                     en
# 83627                    NaN
# 83628                     en
# 83629                     en
# 83630                     en
# 83632                     en
# 83633                     en
# 83634                     en
# 83635                     en
# 83636                     en
# 83639                     en
# 83642                     fr
# 83643                     fr
# 83644                     es
# 83645                     fr
# 83646                     en
#
#                                          Cmt1_translated
# 1      The activities of the Engie Group are in line ...
# 2      ENGIE's mission: leader in energy transition W...
# 3      - Variety of opportunities / job mobility - Ab...
# 4      Developing access to energy is a major motivat...
# 6      Mobility, diverse staff and socially conscious...
# 7      - Membership of a large group; - My contributi...
# 8      Increasing responsibility. Transparency of man...
# 9      I enjoy working for ENGIE as it allows me the ...
# 10                                                   NaN
# 11                         Contacts with clients on site
# 12                 Transparency and spirit of evolution.
# 13     1 An abundance of opportunities for personal g...
# 14     I AM NOT HAPPY WORKING AT AVON PEAKING POWER P...
# 15     The Company is still developing in Northern Ca...
# 16     I am proud of being part of company that promo...
# 17     The Engie BU is a good place for career growth...
# 18                          Safety is the first priority
# 19     The opportunities that await, for doing good w...
# 20                              ENGIE life saving rules.
# 21     I don't think I have any long-term professiona...
# 22                                                    ??
# 23     Its a more professional company with inspiring...
# 24                                                   NaN
# 26     Care for environment and its employees. Develo...
# 28     Employees must be paid if they work holidays a...
# 30     Everyone need to get paid according to the wor...
# 31     The adversity provided to accommodate everyone...
# 32     i am unable to actually answer this question t...
# 33     I am glad working under Engie and I do believe...
# 34     It will help and give us courage to be appreci...
# ...                                                  ...
# 83604  The energy and dedication of my fellow employe...
# 83605  I like the steps we're taking as part of the z...
# 83606  Learning & development programs should be impl...
# 83607                              The work environment.
# 83611                        the forward thinking vision
# 83614  Socially responsible. Prioritizing sustainabil...
# 83615                                                NaN
# 83616  The opportunity to grow professionally. This i...
# 83617  Identified with its purpose International cult...
# 83618  The purpose of our company, the impact we want...
# 83619  1/ I 200% align myself with ENGIE's vision. EN...
# 83620  I am very impressed with the radical decisions...
# 83622  Being able to help customers meet their financ...
# 83623  The renewable and diversified industry that we...
# 83625  I don't feel like I am at work I feel like I a...
# 83627                                                NaN
# 83628  I like that working for ENGIE has given me the...
# 83629  The people I work with on my team. There is a ...
# 83630  Innovative culture to lead clients to new ener...
# 83632  Work/Life balance, great projects for our cust...
# 83633  Environment is challenging/safe and impressed ...
# 83634                    Engie is a good place to work .
# 83635  Diversity, flexibility, opportunities for grow...
# 83636  What I like most about working at ENGIE is the...
# 83639                         The People and my Director
# 83642  The positioning of the company, at the forefro...
# 83643        the freedom that my supervisor has left me!
# 83644  (i) Your strategy, which has maintained consis...
# 83645  The zero carbon strategy, the committed people...
# 83646  In GEM most of us have or have had the chance ...
#
# [53558 rows x 14 columns]

# %%
df.to_csv("translation_set.csv",sep=";")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-8ab9b7dc556a> in <module>
# ----> 1 df.to_csv("translation_set.csv",sep=";")
#
# NameError: name 'df' is not defined
